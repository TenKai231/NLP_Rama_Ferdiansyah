# %%
with open('model/tfidf.pkl', 'rb') as f:
    tfidf = pickle.load(f)
# Out:
# /mnt/DATA/proyek/bejar_python/venv/lib/python3.14/site-packages/sklearn/base.py:463: InconsistentVersionWarning: Trying to unpickle estimator TfidfTransformer from version 1.6.1 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /mnt/DATA/proyek/bejar_python/venv/lib/python3.14/site-packages/sklearn/base.py:463: InconsistentVersionWarning: Trying to unpickle estimator TfidfVectorizer from version 1.6.1 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
new_text = [
    "aplikasinya sangat bagus dan cepat"
]

# %%
# Transform
new_text_tfidf = tfidf.transform(new_text)

# %%
model = load_model(
    '/model/sentiment_model.h5',
    compile=False
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 model = load_model(
#       2     '/model/sentiment_model.h5',
#       3     compile=False
#       4 )
#
# NameError: name 'load_model' is not defined

# %%
# Predict
prediction = model.predict(new_text_tfidf)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step

# %%
prediction = model.predict(new_text_tfidf)

predicted_class = prediction.argmax(axis=1)

label_map = {
    0: "negatif",
    1: "netral",
    2: "positif"
}

print("Prediction :", label_map[predicted_class[0]])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Prediction : positif

# %%
print(predicted_class)
print(predicted_class.shape)
# Out:
# [2]
# (1,)

# %%
confidence = prediction.max()

print("Confidence :", confidence)
# Out:
# Confidence : 0.9984816
